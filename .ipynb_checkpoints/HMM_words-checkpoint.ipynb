# %%
import json
from pprint import pprint
import numpy as np

#opening the tweet data files
# with open('condensed_2011.json') as data_file:    
#     data2011 = json.load(data_file)
# with open('condensed_2012.json') as data_file:    
#     data2012 = json.load(data_file)
# with open('condensed_2013.json') as data_file:    
#     data2013 = json.load(data_file)
# with open('condensed_2014.json') as data_file:    
#     data2014 = json.load(data_file)
with open('condensed_2015.json') as data_file:    
    data2015 = json.load(data_file)
with open('condensed_2016.json') as data_file:    
    data2016 = json.load(data_file)
with open('condensed_2017.json') as data_file:    
    data2017 = json.load(data_file)

#storing the data in a single variable
tweets=[]
# for i in range(len(data2011)-1):
#     tweets.append(data2011[i]["text"])
# for i in range(len(data2012)-1):
#     tweets.append(data2012[i]["text"])
# for i in range(len(data2013)-1):
#     tweets.append(data2013[i]["text"])
# for i in range(len(data2014)-1):
#     tweets.append(data2014[i]["text"])
for i in range(len(data2015)-1):
    tweets.append(data2015[i]["text"])
for i in range(len(data2016)-1):
    tweets.append(data2016[i]["text"])
for i in range(len(data2017)-1):
    tweets.append(data2017[i]["text"])   
    
tweet_words=[]
for i in range(len(tweets)):
    tweet_words.append(tweets[i].split(' '))  

unique_dict=[]
for i in range(len(tweet_words)-1):
    for j in range(len(tweet_words[i])-1):
        if tweet_words[i][j] not in unique_dict:
            unique_dict.append(tweet_words[i][j])

# %%
unique_dict.insert(0,' ')
unique_dict
# Out:
# [' ',
#  'I',
#  'would',
#  'like',
#  'to',
#  'wish',
#  'everyone',
#  'A',
#  'HAPPY',
#  'AND',
#  'HEALTHY',
#  'NEW',
#  'YEAR.',
#  'WE',
#  'MUST',
#  'ALL',
#  'WORK',
#  'TOGETHER',
#  'TO,',
#  'FINALLY,',
#  'MAKE',
#  'AMERICA',
#  'SAFE',
#  'AGAIN',
#  'GREAT',
#  'Do',
#  'you',
#  'believe',
#  'that',
#  'The',
#  'State',
#  'Department,',
#  'on',
#  "YEAR'S",
#  'EVE,',
#  'just',
#  'released',
#  'more',
#  'of',
#  "Hillary's",
#  'e-mails.',
#  'They',
#  'want',
#  'it',
#  'all',
#  'end.',
#  'THANK',
#  'YOU',
#  'ILLINOIS!',
#  "Let's",
#  'not',
#  'forget',
#  'get',
#  'family',
#  '&amp;',
#  'friends-',
#  'out',
#  'VOTE',
#  'IN',
#  '2016!',
#  'https://t.co/lg5kMbNLYK',
#  'BIRTHDAY',
#  'my',
#  'son,',
#  '@DonaldJTrumpJr!',
#  'Very',
#  'proud',
#  'you!',
#  '#TBT',
#  'https://t.co/ULerCEOCGX',
#  'feel',
#  'sorry',
#  'for',
#  '@JebBush',
#  'and',
#  'how',
#  'badly',
#  'he',
#  'is',
#  'doing',
#  'with',
#  'his',
#  'campaign',
#  'other',
#  'than',
#  'the',
#  'fact',
#  'took',
#  'millions',
#  "$'s",
#  'hit',
#  'ads',
#  '#MakeAmericaGreatAgain',
#  '#Trump2016',
#  '"@whispers34:',
#  'Nevada',
#  'Poll:',
#  'Donald',
#  'Trump',
#  '33%,',
#  'Ted',
#  'Cruz',
#  '20%,',
#  'Marco',
#  'Rubio',
#  '11%...',
#  'https://t.co/Hniy4iAqNG',
#  'via',
#  '@thelastrefuge2"',
#  '',
#  'Great',
#  '"@deggow:',
#  'Just',
#  'heard',
#  'a',
#  '25',
#  'year',
#  'old',
#  'man',
#  'say',
#  '"I',
#  'rather',
#  'work',
#  'Bernie',
#  'Sanders"it\'s',
#  'time',
#  'me',
#  'leave',
#  'this',
#  '"@wmsolomon:',
#  "'On",
#  "Point'",
#  'Gov.',
#  'Sarah',
#  'Palin',
#  '"@stylin1188:',
#  'running',
#  'most',
#  'cost-effective',
#  'presidential',
#  'in',
#  'modern',
#  'history',
#  'https://t.co/iGyTDDEpbv"',
#  'Thank',
#  '"@SenSanders:',
#  'have',
#  'message',
#  'Trump:',
#  'No,',
#  'we’re',
#  'going',
#  'hate',
#  'Latinos,',
#  'Muslims."',
#  'fully',
#  '"@BretBaier:',
#  ".@realDonaldTrump's",
#  'reaction',
#  '@LindseyGrahamSC',
#  'dropping',
#  '2016',
#  'race.',
#  'Your',
#  'thoughts?',
#  '"@InsideGym:',
#  'Most',
#  'Influential',
#  'U.S.',
#  'Gymnasts',
#  'Of',
#  'All',
#  'Time:',
#  'https://t.co/DIGT1wLIx4',
#  '@NastiaLiukin',
#  '@ShawnJohnson',
#  '@ASAQ_3"',
#  'Fantastic',
#  'People',
#  'ask,',
#  '"why',
#  'do',
#  'tweet',
#  're-tweet',
#  'about',
#  'when',
#  'so',
#  'low',
#  'polls?"',
#  'Because',
#  'big',
#  '$',
#  '"@ddpick18:',
#  '@realDonaldTrump',
#  '@hughhewitt',
#  'pissed',
#  'off',
#  'every',
#  'see',
#  'Fox.',
#  'Waste',
#  'money!',
#  'Go',
#  'Trump!"',
#  'Many',
#  '"@nikkisue69:',
#  'Jeb',
#  'such',
#  '"@Luciano031982:',
#  'Veterans',
#  'Love',
#  'Trump"',
#  'But',
#  'love',
#  'VETS',
#  'even',
#  '"@Trump2016Donald:',
#  'Patriots',
#  'trump!',
#  '.@JebBush',
#  'has',
#  'spent',
#  '$63,000,000',
#  'at',
#  'bottom',
#  'polls.',
#  'almost',
#  'nothing',
#  'am',
#  'top.',
#  'WIN!',
#  '"@BentleyforTrump:',
#  'OF',
#  'LOVES',
#  'TRUMP!👍👍☺',
#  '#TrumpOrNobody2016',
#  '#MakeAmericaGreatAgain"',
#  'day',
#  'South',
#  'Carolina.',
#  'Record',
#  'crowd',
#  'fantastic',
#  'enthusiasm.',
#  'This',
#  'now',
#  'movement',
#  'predict',
#  'dying',
#  '@UnionLeader',
#  'newspaper,',
#  'which',
#  'been',
#  'run',
#  'into',
#  'ground',
#  'by',
#  'publisher',
#  '"Stinky"',
#  'Joe',
#  'McQuaid,',
#  'will',
#  'be',
#  'dead',
#  '2',
#  'lovely',
#  'letter',
#  'from',
#  'daughter',
#  'late',
#  'great',
#  'John',
#  'Wayne.',
#  'Our',
#  'country',
#  'could',
#  'use',
#  'Wayne',
#  'right',
#  'now.',
#  'poll-',
#  'thank',
#  'Nevada!\n#MakeAmericaGreatAgain',
#  "I'm",
#  'live',
#  '@ericbolling',
#  '@kimguilfoyle',
#  'ring',
#  'New',
#  'Year',
#  '2016.',
#  'Everybody',
#  'should',
#  'tune',
#  '@foxnews',
#  'tomorrow',
#  'Hilton',
#  'Head,',
#  'Carolina!',
#  '@SCTeamTrump',
#  'https://t.co/RLCz17tIas',
#  'never',
#  'thought',
#  "I'd",
#  'saying',
#  'but',
#  "I've",
#  'really',
#  'enjoyed',
#  '@RichLowry',
#  'television',
#  'lately,',
#  'was',
#  'terrific',
#  'hosting',
#  'McQuaid',
#  '(@deucecrew)',
#  'desperately',
#  'trying',
#  'sell',
#  '@UnionLeader.',
#  "It's",
#  'loser,',
#  'comments',
#  "haven't",
#  'helped',
#  'him',
#  'newspaper',
#  'NH',
#  'turmoil',
#  'over',
#  'them-',
#  'bully',
#  'got',
#  'knocked',
#  '"@TruthisAll1:',
#  '@CharlesHurt',
#  '@seanhannity',
#  'Good',
#  'morning,',
#  'Mr.',
#  'Trump.',
#  "You're",
#  'AWESOME.',
#  '"@bfb123456:',
#  '@trumpiowa',
#  '@PlaysTrumpCard',
#  'WOW!',
#  'FANTASTIC!.',
#  'WHO',
#  'KNEW',
#  'AMERICANS',
#  'WERE',
#  'SO',
#  'SMART?',
#  'TO',
#  'KNOW',
#  "WE'RE",
#  '"@hammetjohn:',
#  'DonaldTrump',
#  '-',
#  'How',
#  'u',
#  'Donald.',
#  'No',
#  'one',
#  'keep',
#  'up',
#  'your',
#  'pace.',
#  'Shows',
#  'hard',
#  'us',
#  'as',
#  '"@videosigninc:',
#  'Keep',
#  'momentum',
#  'best',
#  'Year.',
#  'Make',
#  'America',
#  'Again',
#  '!"',
#  '"@Hashtag1USA:',
#  'what',
#  'think',
#  'cancelling',
#  'Iowa',
#  'rally',
#  'last',
#  'night',
#  '?',
#  'https://t.co/1oe798AAEU"',
#  'went,',
#  'night,',
#  'amazing',
#  'people.',
#  'Florida,',
#  'getting',
#  'ready',
#  'go',
#  'Big',
#  'crowd,',
#  'very',
#  '.@CharlesHurt',
#  'You',
#  'were',
#  'night.',
#  'Thanks',
#  'nice',
#  'words.',
#  'Council',
#  'Bluffs,',
#  'Iowa!',
#  'silent',
#  'majority,',
#  'no',
#  'more!\n#Trump2016',
#  '#FITN',
#  'https://t.co/VTAe68eQ1k',
#  'Union',
#  'Leader',
#  'wanted',
#  'ads,',
#  'lunches,',
#  'donations,',
#  'speeches',
#  'me,',
#  'tweets---very',
#  'people',
#  'Hampshire,',
#  'who',
#  'love,',
#  'are',
#  'properly',
#  'served',
#  'dumb',
#  'put',
#  'wrote',
#  'why',
#  "didn't",
#  'failed',
#  'hope',
#  '@TGowdySC',
#  'does',
#  'better',
#  'did',
#  '#Benghazi',
#  'hearings,',
#  'total',
#  'disaster',
#  'Republicans',
#  'We',
#  'need',
#  'real',
#  'President!',
#  'Looking',
#  'forward',
#  'being',
#  'Iowa,',
#  'later',
#  'today.',
#  'Despite',
#  'weather,',
#  '--',
#  'fantastic!',
#  'So,',
#  'president',
#  '1st',
#  'place.',
#  'Bush',
#  '$59',
#  'million',
#  'done.',
#  'Run',
#  'My',
#  '$35,000,000',
#  'under',
#  'budget,',
#  'little',
#  '(and',
#  'place).Now',
#  'spend',
#  '"Minorities',
#  'line',
#  'behind.....Donald',
#  'https://t.co/cEMKihLZbK',
#  '.@jessebwatters',
#  '@FoxNews',
#  'gets',
#  'Remember',
#  'Bill',
#  'Clinton',
#  'brought',
#  'help',
#  'Hillary',
#  'against',
#  'Obama',
#  '2008.',
#  'He',
#  'terrible,',
#  'badly,',
#  'called',
#  '"@LeeMiracle3:',
#  'listening',
#  'voters,',
#  'unlike',
#  '"@umakemeill:',
#  '@HillaryClinton',
#  '"@IJNIPGM:',
#  'casualties.',
#  'victory,',
#  'victory',
#  'proclaim',
#  'truth',
#  'heart.',
#  'God',
#  '"@sunquist007:',
#  'Why',
#  'attack',
#  'Trump?',
#  'Really',
#  'strategy!',
#  'U',
#  'lose,',
#  'wins!',
#  '#lets',
#  'make',
#  '"@slone:',
#  'FLASHBACK1986:',
#  'Saved',
#  'Georgia',
#  'Farm',
#  'https://t.co/EoKDLePxUR',
#  'https://t.co/MaEHiEQoMI"',
#  'you,',
#  'you-',
#  'Nashua,',
#  'Hampshire!',
#  '\n#NHPolitics',
#  'https://t.co/QPj5gb3wib',
#  '\nhttps://t.co/dTL7uybyeH',
#  'supporter',
#  'video',
#  'campaign-',
#  'past',
#  '6',
#  'months.',
#  'Video:',
#  'Strange,',
#  'wacko',
#  'Sanders',
#  'allies',
#  'coming',
#  'because',
#  'lowering',
#  'taxes,',
#  'while',
#  'double',
#  'triple',
#  'them,',
#  'Wages',
#  'too',
#  'low,',
#  'good',
#  'jobs',
#  'few,',
#  'lost',
#  'faith',
#  'our',
#  'leaders.We',
#  'smart',
#  'strong',
#  'leadership',
#  'long',
#  'gone,',
#  'shipped',
#  'countries.',
#  'part',
#  'time,',
#  'sad!',
#  'WILL',
#  'middle-class',
#  'worked',
#  'hard,',
#  'kind',
#  'they',
#  'dreamed',
#  'effective',
#  'raise',
#  'years.',
#  'If',
#  'thinks',
#  'she',
#  'can',
#  'unleash',
#  'her',
#  'husband,',
#  'terrible',
#  'record',
#  'women',
#  'abuse,',
#  'playing',
#  "women's",
#  'card',
#  "she's",
#  '"@BornToBeGOP:',
#  'President',
#  'things',
#  'done,',
#  "that's",
#  'we',
#  'you!"',
#  'Hopefully',
#  'Republican',
#  'National',
#  'Committee',
#  'straighten',
#  'mess',
#  'taking',
#  'place',
#  "Virginia's",
#  'Party.',
#  'Straighten',
#  'Party',
#  'Virginia',
#  'before',
#  'late.',
#  'Stupid!',
#  '.@BernieSanders-who',
#  'blew',
#  'gave',
#  'pass',
#  'e-mail',
#  'crime,',
#  'said',
#  'wages',
#  'high.',
#  'voters',
#  'excluding',
#  'doom',
#  'any',
#  'chance',
#  'victory.',
#  'Dems',
#  'LOVE',
#  'IT!',
#  'Be',
#  'win',
#  'R.P.Virginia',
#  'statewide',
#  '7',
#  'times',
#  'row.',
#  'Will',
#  'allow',
#  'needed',
#  'new',
#  'voters.',
#  'Suicidal',
#  'mistake.',
#  'RNC',
#  'ACT',
#  'It',
#  'begins,',
#  'Virginia,',
#  'controlled',
#  'RNC,',
#  'working',
#  'disallow',
#  'independent,',
#  'unaffiliated',
#  '"@CAC8438:',
#  'supports',
#  'amnesty',
#  'desperate',
#  'Trey',
#  'Gowdy',
#  '"@mitchellvii:',
#  'prediction',
#  'endorsement',
#  'finish',
#  'Face',
#  'it,',
#  'miserably',
#  'Benghazi.',
#  'allowed',
#  'drag',
#  'end,',
#  'let',
#  'away',
#  '"@Sir_Max:',
#  'andreajmarkley:',
#  'finally',
#  'an',
#  '–',
#  'loser',
#  '#Tcot',
#  '#pjnet',
#  'https://t.co/lJcHG0IHaM',
#  'far',
#  'Hillary,',
#  'safe,',
#  'something',
#  'able',
#  'do-no',
#  '#Trump2016\nhttps://t.co/CE9f0mukFm',
#  'announced',
#  'letting',
#  'husband',
#  "HE'S",
#  'DEMONSTRATED',
#  'PENCHANT',
#  'FOR',
#  'SEXISM,',
#  '"@greta:',
#  'insurance',
#  'companies',
#  'making',
#  'lots',
#  'money',
#  '#',
#  'uninsured',
#  'still',
#  'large,Obamacare',
#  'failure',
#  'since',
#  'terror',
#  'warning',
#  'issued',
#  'European',
#  'cties.',
#  'At',
#  'point',
#  'had',
#  'enough',
#  'tough',
#  'smart.',
#  'Weak',
#  '\nStory:',
#  'https://t.co/PBOKbGIaVB',
#  'Criminal',
#  'deportations',
#  'lowest',
#  'number',
#  'many',
#  'criminals',
#  'knowingly',
#  'stay',
#  'country.',
#  'Phoenix',
#  'V.A.,',
#  'reported,',
#  'worse',
#  'shape',
#  'ever',
#  'before.',
#  'wait',
#  'horrendous,',
#  'dying.',
#  'fix',
#  'same',
#  "wouldn't",
#  'run,',
#  'or',
#  'lead',
#  'well',
#  '(1st',
#  'leading',
#  '21%),',
#  "won't",
#  'beat',
#  '.@chucktodd',
#  'dishonest',
#  'reporting...and',
#  'air',
#  'until',
#  'came',
#  'along-no',
#  'ratings.',
#  '@CNN',
#  'TRUMP',
#  '#1',
#  'story',
#  '2015.',
#  'Totally',
#  'meaningless,',
#  'however,',
#  'if',
#  "don't",
#  'WIN',
#  'IT',
#  '"@deedeegop:',
#  'Trump,',
#  'look',
#  'elected',
#  'next',
#  'United',
#  'States',
#  '#MakeAmericaGreatAgain.',
#  'So',
#  '"@JodiL792:',
#  'know',
#  "what's",
#  'Christmas',
#  'Great,',
#  'Family/food/friends&amp;YOU!',
#  'HAVE',
#  'MY',
#  'SHIRT',
#  'ON',
#  'W/HOPE',
#  'HEART',
#  '"@Jacobsac2015:',
#  'today',
#  'Christmas.',
#  "Can't",
#  'President,',
#  '"@ClassySnobbb:',
#  'reading',
#  '#CrippledAmerica!',
#  'Best',
#  'book',
#  'ever.',
#  'When',
#  'Democrats,',
#  'particular,',
#  '"we',
#  'must',
#  'build',
#  'wall,',
#  'Mexico',
#  'pay',
#  'it?"',
#  'VETERANS',
#  'treated',
#  'corruption',
#  'incompetence',
#  'V.A.',
#  'That',
#  'stop,',
#  'candidate',
#  'illegals',
#  'across',
#  'border',
#  'AN',
#  'LOVE?',
#  "He's",
#  'problems',
#  'house',
#  '(country!),',
#  'them',
#  'visitors',
#  'come',
#  'stay.',
#  'Does',
#  'Democrats',
#  'now,',
#  'starting',
#  'deport',
#  'here',
#  'illegally.',
#  '.@deedeesorvino',
#  'She',
#  'politics,',
#  'sees',
#  'clearly.',
#  'Have',
#  'Merry',
#  'all.',
#  'year.',
#  'Together,',
#  'AGAIN!',
#  '.@danielhalper',
#  'job',
#  'wise',
#  '.@HallieJackson',
#  'report',
#  'lying',
#  'ISIS',
#  'video.',
#  'Bad',
#  'reporting.',
#  'Perhaps',
#  '@NBC',
#  'year-but',
#  'doubt',
#  '"@YesMrGilbert:',
#  '@NBCNightlyNews',
#  '@HallieJackson',
#  'talked',
#  'Megyn',
#  'Kelly',
#  'story"',
#  'True,',
#  'distortion',
#  'Palm',
#  'Beach,',
#  'church',
#  'tonight.',
#  '.@meetthepress',
#  '@chucktodd',
#  'showing',
#  'Poll',
#  'where',
#  '39%,',
#  '21points',
#  'higher',
#  'Cruz.',
#  'honest',
#  "isn't",
#  'using',
#  'much',
#  'newer',
#  'discussing',
#  'instead',
#  'older',
#  'Q',
#  'Poll?',
#  'CNN',
#  'Wow,',
#  'pressure',
#  'ICE',
#  'LAUNCH',
#  'LARGE',
#  'SCALE',
#  'DEPORTATION',
#  'RAIDS.',
#  'Next',
#  'interesting',
#  'one.',
#  'Clinton,',
#  'totally',
#  'flawed',
#  'candidate,',
#  'beating',
#  'Third',
#  'rate',
#  'reporters',
#  'Amy',
#  'Chozick',
#  'Maggie',
#  'Haberman',
#  'failing',
#  '@nytimes',
#  'circle',
#  'bias.',
#  'Think',
#  'lowly',
#  'Rand',
#  'Paul',
#  'Poll.',
#  '3%,',
#  '39%.',
#  'Stop',
#  'throwing',
#  'down',
#  'In',
#  'ridiculous',
#  'ad',
#  'speaking',
#  'during',
#  'debate,',
#  "doesn't",
#  'answer,',
#  'destroys',
#  'Poor',
#  '$50',
#  'campaign,',
#  'nothing.',
#  'gone),',
#  'top',
#  '(by',
#  'lot).',
#  "That's",
#  '"@classyexplorer:',
#  '@gatewaypundit',
#  'Jim',
#  'fail',
#  'mention',
#  'POLL',
#  'GOP',
#  'RACE...Trump',
#  '39',
#  '18...Big',
#  'movie',
#  'perfect',
#  '#TBT!',
#  'https://t.co/qUpZphfhV3',
#  '"@ihatematt:',
#  'run...',
#  "She's",
#  'criminal."',
#  'deplore',
#  'tone',
#  'inflammatory',
#  'rhetoric',
#  'campaign."',
#  'death',
#  'destruction',
#  ...]

# %%
lengths=np.zeros(len(tweet_words))
for i in range(len(tweet_words)):
    lengths[i]=len(tweet_words[i])
ave_len=int(lengths.mean())

# prob=np.zeros(len(unique_dict))
# for i in range(len(tweet_words)-1):
#     for k in range(len(tweet_words[i])):
#         for j in range(len(unique_dict)-1):
#             if tweet_words[i][k]==unique_dict[j]:
#                 prob[j]=prob[j]+1
# prob=prob/len(tweet_words)

# %%
numeric_map=range(1,np.size(unique_dict))

index=0
max_chars=140
hid_states=np.zeros(int(np.size(tweet_words)*max(lengths)))
for i in range(len(tweet_words)):
    for k in range(len(tweet_words[i])):
        for j in range(len(unique_dict)):
            if tweet_words[i][k]==unique_dict[j]:
                hid_states[index]=j
                index=index+1

# from nltk.corpus import treebank
# tweet_words=np.asarray(tweet_words)
# trainer= nltk.tag.hmm.HiddenMarkovModelTrainer(symbols=unique_dict)
# trainer=trainer.train_unsupervised(tweet_words)

# %%
hid=np.zeros((np.size(tweet_words),int(max(lengths))))
for i in range(np.size(tweet_words)-1):
    for j in range(len(tweet_words[i])-1):
        if len(tweet_words[i])<140:
            hid[i,j]=hid_states[i+i*j]

hid=hid[1:-4]

# %%
from hmmlearn import hmm
from hmmlearn import base
import warnings
warnings.filterwarnings(action='ignore')

model=hmm.GaussianHMM(n_components=100,n_iter=5)
model.fit(hid)

# %%
x,state_seq=model.sample(n_samples=np.random.randint(0,max(lengths)));
seq=[]
for i in range(len(state_seq)):
    seq.append(unique_dict[state_seq[i]])
seq
# Out:
# ['millions',
#  'VOTE',
#  'out',
#  'forget',
#  '#MakeAmericaGreatAgain',
#  '&amp;',
#  'he',
#  '&amp;',
#  '@DonaldJTrumpJr!',
#  'get',
#  'believe',
#  'out',
#  '&amp;',
#  'believe',
#  '#MakeAmericaGreatAgain',
#  'out',
#  'forget',
#  '&amp;',
#  '&amp;']

# %%
state_seq=model._generate_sample_from_state(50);
seq=[]
for i in range(len(state_seq)):
    if(unique_dict[int(state_seq[i])]!=' '):
        seq.append(unique_dict[int(state_seq[i])])
seq
# Out:
# ['Independent',
#  'husband,',
#  '@DavidMuir',
#  'suggests',
#  'AMERICA',
#  '"There’s',
#  '.@jessebwatters',
#  '"Trump"',
#  'weakening',
#  'provides',
#  'doing',
#  'reference',
#  'bully',
#  'Chevy',
#  'Coming',
#  'my',
#  'winning',
#  'Chair.',
#  'Vegas,',
#  'ground',
#  '"@BentleyforTrump:',
#  'his',
#  'Donald.',
#  'landing',
#  'Nevada']
